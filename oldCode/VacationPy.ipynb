# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df = pd.read_csv("../output_data/cities_550.csv")
del df["Unnamed: 0"]
df
# Out:
#                                                   JSON                 DATE  \
# 0    {'coord': {'lon': -175.2, 'lat': -21.2}, 'weat...  2022-07-31 02:58:16
# 1    {'coord': {'lon': -122.4286, 'lat': 37.4636}, ...  2022-07-31 02:58:18
# 2    {'coord': {'lon': 168.3333, 'lat': -46.6}, 'we...  2022-07-31 02:58:19
# 3    {'coord': {'lon': -79.2353, 'lat': 42.097}, 'w...  2022-07-31 02:58:21
# 4    {'coord': {'lon': -73.9662, 'lat': 42.6001}, '...  2022-07-31 02:57:37
# ..                                                 ...                  ...
# 498  {'coord': {'lon': -157.8378, 'lat': 21.4447}, ...  2022-07-31 03:15:04
# 499  {'coord': {'lon': 36.8595, 'lat': 49.4627}, 'w...  2022-07-31 03:15:06
# 500  {'coord': {'lon': -60.2177, 'lat': 46.2367}, '...  2022-07-31 03:15:09
# 501  {'coord': {'lon': 44.8414, 'lat': 51.5506}, 'w...  2022-07-31 03:15:11
# 502  {'coord': {'lon': -65.1023, 'lat': -43.3002}, ...  2022-07-31 03:15:13
#
#               CITY COUNTRY      LAT       LNG  MAX_TEMP  HUMIDITY  CLOUDINESS  \
# 0            Vaini      TO -21.2000 -175.2000     80.76      89.0        40.0
# 1    Half Moon Bay      US  37.4636 -122.4286     62.33      87.0       100.0
# 2            Bluff      NZ -46.6000  168.3333     47.80      77.0        49.0
# 3        Jamestown      US  42.0970  -79.2353     61.48      55.0         1.0
# 4           Albany      US  42.6001  -73.9662     65.89      78.0         0.0
# ..             ...     ...      ...       ...       ...       ...         ...
# 498      ‘Āhuimanu      US  21.4447 -157.8378     81.55      71.0        75.0
# 499      Balakliya      UA  49.4627   36.8595     60.71      71.0         0.0
# 500   Sydney Mines      CA  46.2367  -60.2177     64.26      94.0        75.0
# 501    Lysyye Gory      RU  51.5506   44.8414     65.25      86.0       100.0
# 502         Rawson      AR -43.3002  -65.1023     44.24      61.0        88.0
#
#      WIND_SPEED
# 0         10.36
# 1         16.11
# 2         16.26
# 3          1.63
# 4          4.85
# ..          ...
# 498       16.11
# 499        6.76
# 500       10.36
# 501        9.40
# 502        7.27
#
# [503 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
locations = df[["LAT", "LNG"]]

weights = df["HUMIDITY"]

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=weights, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows with null values.

# %%
best_cities_df = df.loc[ (df["MAX_TEMP"].between(69, 84)) & (df["HUMIDITY"] < 80) & (df["CLOUDINESS"] < 50), :]
best_cities_df.dropna()
best_cities_df
# Out:
#                                                   JSON                 DATE  \
# 10   {'coord': {'lon': -114.0611, 'lat': 27.9769}, ...  2022-07-31 02:58:37
# 35   {'coord': {'lon': -134.9692, 'lat': -23.1203},...  2022-07-31 02:59:30
# 37   {'coord': {'lon': -139.0333, 'lat': -9.8}, 'we...  2022-07-31 02:59:34
# 41   {'coord': {'lon': -159.775, 'lat': -21.2078}, ...  2022-07-31 02:59:41
# 48   {'coord': {'lon': -17.1, 'lat': 32.6667}, 'wea...  2022-07-31 02:59:55
# ..                                                 ...                  ...
# 458  {'coord': {'lon': -108.1833, 'lat': 25.3667}, ...  2022-07-31 03:13:42
# 464  {'coord': {'lon': 118.7833, 'lat': 42.1167}, '...  2022-07-31 03:13:54
# 466  {'coord': {'lon': 17.1369, 'lat': 42.9622}, 'w...  2022-07-31 03:13:58
# 470  {'coord': {'lon': 10.85, 'lat': 30.3333}, 'wea...  2022-07-31 03:14:06
# 496  {'coord': {'lon': -48.555, 'lat': -6.4006}, 'w...  2022-07-31 03:14:58
#
#                         CITY COUNTRY      LAT       LNG  MAX_TEMP  HUMIDITY  \
# 10            Guerrero Negro      MX  27.9769 -114.0611     70.70      77.0
# 35                   Rikitea      PF -23.1203 -134.9692     72.93      75.0
# 37                    Atuona      PF  -9.8000 -139.0333     76.68      78.0
# 41                    Avarua      CK -21.2078 -159.7750     78.85      69.0
# 48              Ponta do Sol      PT  32.6667  -17.1000     69.94      79.0
# ..                       ...     ...      ...       ...       ...       ...
# 458                Angostura      MX  25.3667 -108.1833     82.00      72.0
# 464              Mujiayingzi      CN  42.1167  118.7833     83.73      50.0
# 466                  Korčula      HR  42.9622   17.1369     76.62      68.0
# 470                    Nālūt      LY  30.3333   10.8500     78.46      28.0
# 496  São Geraldo do Araguaia      BR  -6.4006  -48.5550     77.40      53.0
#
#      CLOUDINESS  WIND_SPEED
# 10          5.0       13.85
# 35          9.0       15.93
# 37         14.0       14.43
# 41         40.0       20.71
# 48         14.0        6.98
# ..          ...         ...
# 458        10.0        3.76
# 464        15.0        6.82
# 466         0.0        7.02
# 470         0.0       10.36
# 496         1.0        1.16
#
# [62 rows x 10 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = best_cities_df.head(10).copy()

hotel_df["HOTEL_PLACEID"] = "NULL"
hotel_df["HOTEL_NAME"] = "NULL"
hotel_df["HOTEL_CITY"] = "NULL"
hotel_df["HOTEL_COUNTRY"] = "NULL"

hotel_df
# Out:
#                                                   JSON                 DATE  \
# 10   {'coord': {'lon': -114.0611, 'lat': 27.9769}, ...  2022-07-31 02:58:37
# 35   {'coord': {'lon': -134.9692, 'lat': -23.1203},...  2022-07-31 02:59:30
# 37   {'coord': {'lon': -139.0333, 'lat': -9.8}, 'we...  2022-07-31 02:59:34
# 41   {'coord': {'lon': -159.775, 'lat': -21.2078}, ...  2022-07-31 02:59:41
# 48   {'coord': {'lon': -17.1, 'lat': 32.6667}, 'wea...  2022-07-31 02:59:55
# 71   {'coord': {'lon': -158.1547, 'lat': 21.3906}, ...  2022-07-31 03:00:40
# 75   {'coord': {'lon': -149.8667, 'lat': -17.5667},...  2022-07-31 03:00:47
# 88   {'coord': {'lon': 18.8162, 'lat': -5.041}, 'we...  2022-07-31 03:01:12
# 105  {'coord': {'lon': -89.0928, 'lat': 30.3674}, '...  2022-07-31 02:57:51
# 121  {'coord': {'lon': 93.0344, 'lat': 58.0728}, 'w...  2022-07-31 03:02:19
#
#                CITY COUNTRY      LAT       LNG  MAX_TEMP  HUMIDITY  \
# 10   Guerrero Negro      MX  27.9769 -114.0611     70.70      77.0
# 35          Rikitea      PF -23.1203 -134.9692     72.93      75.0
# 37           Atuona      PF  -9.8000 -139.0333     76.68      78.0
# 41           Avarua      CK -21.2078 -159.7750     78.85      69.0
# 48     Ponta do Sol      PT  32.6667  -17.1000     69.94      79.0
# 71         Nānākuli      US  21.3906 -158.1547     83.34      67.0
# 75          Haapiti      PF -17.5667 -149.8667     79.72      66.0
# 88           Kikwit      CD  -5.0410   18.8162     74.08      40.0
# 105        Gulfport      US  30.3674  -89.0928     73.74      71.0
# 121         Strelka      RU  58.0728   93.0344     74.44      71.0
#
#      CLOUDINESS  WIND_SPEED HOTEL_PLACEID HOTEL_NAME HOTEL_CITY HOTEL_COUNTRY
# 10          5.0       13.85          NULL       NULL       NULL          NULL
# 35          9.0       15.93          NULL       NULL       NULL          NULL
# 37         14.0       14.43          NULL       NULL       NULL          NULL
# 41         40.0       20.71          NULL       NULL       NULL          NULL
# 48         14.0        6.98          NULL       NULL       NULL          NULL
# 71          1.0       14.65          NULL       NULL       NULL          NULL
# 75         14.0       22.12          NULL       NULL       NULL          NULL
# 88         32.0        0.65          NULL       NULL       NULL          NULL
# 105         1.0        8.32          NULL       NULL       NULL          NULL
# 121        35.0        7.09          NULL       NULL       NULL          NULL

# %%
# params dictionary to update each iteration

params = {
    "location": "0,0",
    "radius": 5000,
    "types": "lodging",
    "keyword": "hotel",
    "key": g_key
}

# Use the lat/lng we recovered to identify airports

for index, row in hotel_df.iterrows():
    
    # get lat, lng from df
    
    lat = row["LAT"]
    lng = row["LNG"]

    # change location each iteration while leaving original params in place
    
    params["location"] = f"{lat},{lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    hotel_data = requests.get(base_url, params=params)

    # convert to json
    hotel_json = hotel_data.json()
    # pprint(hotel_json)

#     # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.

    try:
        hotel_df.loc[index, "HOTEL_PLACEID"] = hotel_json["results"][0]["place_id"]
#         hotel_df.loc[index, "HOTEL_CITY"] = hotel_json["results"][0]["plus_code"]["compound_code"].split(",")[0].split(" ", 1)[1]
#         hotel_df.loc[index, "HOTEL_COUNTRY"] = hotel_json["results"][0]["plus_code"]["compound_code"].split(",")[1]
#         # print(f'HOTEL TO ADD: {hotel_json["results"][0]["name"]}')
        
    except (KeyError, IndexError):
        
        print("Missing field/result... skipping.")
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.

# %%
cleanhotel_df = hotel_df.loc[ (hotel_df["HOTEL_PLACEID"] != "NULL"), :]

cleanhotel_df
# Out:
#                                                   JSON                 DATE  \
# 10   {'coord': {'lon': -114.0611, 'lat': 27.9769}, ...  2022-07-31 02:58:37
# 35   {'coord': {'lon': -134.9692, 'lat': -23.1203},...  2022-07-31 02:59:30
# 37   {'coord': {'lon': -139.0333, 'lat': -9.8}, 'we...  2022-07-31 02:59:34
# 41   {'coord': {'lon': -159.775, 'lat': -21.2078}, ...  2022-07-31 02:59:41
# 48   {'coord': {'lon': -17.1, 'lat': 32.6667}, 'wea...  2022-07-31 02:59:55
# 75   {'coord': {'lon': -149.8667, 'lat': -17.5667},...  2022-07-31 03:00:47
# 105  {'coord': {'lon': -89.0928, 'lat': 30.3674}, '...  2022-07-31 02:57:51
# 121  {'coord': {'lon': 93.0344, 'lat': 58.0728}, 'w...  2022-07-31 03:02:19
#
#                CITY COUNTRY      LAT       LNG  MAX_TEMP  HUMIDITY  \
# 10   Guerrero Negro      MX  27.9769 -114.0611     70.70      77.0
# 35          Rikitea      PF -23.1203 -134.9692     72.93      75.0
# 37           Atuona      PF  -9.8000 -139.0333     76.68      78.0
# 41           Avarua      CK -21.2078 -159.7750     78.85      69.0
# 48     Ponta do Sol      PT  32.6667  -17.1000     69.94      79.0
# 75          Haapiti      PF -17.5667 -149.8667     79.72      66.0
# 105        Gulfport      US  30.3674  -89.0928     73.74      71.0
# 121         Strelka      RU  58.0728   93.0344     74.44      71.0
#
#      CLOUDINESS  WIND_SPEED                HOTEL_PLACEID HOTEL_NAME  \
# 10          5.0       13.85  ChIJZ-lVpeL4M4ERoYGbJ6Zrglg       NULL
# 35          9.0       15.93  ChIJib4T7laIJ54RcJ1rUHQ9KXk       NULL
# 37         14.0       14.43  ChIJL4z7-PMhN3YRhdXuLcxVEH4       NULL
# 41         40.0       20.71  ChIJmVoxwbjRV3ERXkJfFo6QLjY       NULL
# 48         14.0        6.98  ChIJU0wF3-hZYAwRokB97zLZkqY       NULL
# 75         14.0       22.12  ChIJlQlAZRqImXYR6WtP_FwQONA       NULL
# 105         1.0        8.32  ChIJX363D8QXnIgRl4mdtez-kJM       NULL
# 121        35.0        7.09  ChIJqUPbn68z0FwRYaXCDz1WF0M       NULL
#
#     HOTEL_CITY HOTEL_COUNTRY
# 10        NULL          NULL
# 35        NULL          NULL
# 37        NULL          NULL
# 41        NULL          NULL
# 48        NULL          NULL
# 75        NULL          NULL
# 105       NULL          NULL
# 121       NULL          NULL

# %%
# params dictionary to update each iteration

params = {
    "place_id": "",
    "key": g_key
}


for index, row in cleanhotel_df.iterrows():
    
    place_id = row["HOTEL_PLACEID"]

    # change location each iteration while leaving original params in place
    
    params["place_id"] = f"{place_id}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/details/json"

    # make request and print url
    address_data = requests.get(base_url, params=params)

    # convert to json
    address_json = address_data.json()
    # pprint(address_json)
    
    


    try:
        
#         hotel_city = address_json["result"]["formatted_address"]
#         hotel_country = address_json["result"]["formatted_address"]
#         hotel_name = address_json["result"]["formatted_address"]
        
        cleanhotel_df.loc[index, "HOTEL_CITY"] = address_json["result"]["formatted_address"]
#         hotel_df.loc[index, "HOTEL_CITY"] = hotel_json["results"][0]["plus_code"]["compound_code"].split(",")[0].split(" ", 1)[1]
#         hotel_df.loc[index, "HOTEL_COUNTRY"] = hotel_json["results"][0]["plus_code"]["compound_code"].split(",")[1]
#         # print(f'HOTEL TO ADD: {hotel_json["results"][0]["name"]}')
        
    except (KeyError, IndexError):
        
        print("Missing field/result... skipping.")
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': 'Paralelo 28',
#                                     'short_name': 'Paralelo 28',
#                                     'types': ['point_of_interest',
#                                               'establishment']},
#                                    {'long_name': 'Carretera Federal 1',
#                                     'short_name': 'México 1',
#                                     'types': ['route']},
#                                    {'long_name': 'Guerrero Negro',
#                                     'short_name': 'Guerrero Negro',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Baja California Sur',
#                                     'short_name': 'B.C.S.',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': 'Mexico',
#                                     'short_name': 'MX',
#                                     'types': ['country', 'political']},
#                                    {'long_name': '23940',
#                                     'short_name': '23940',
#                                     'types': ['postal_code']}],
#             'adr_address': 'Paralelo 28, <span class="street-address">México '
#                            '1</span>, <span class="postal-code">23940</span> '
#                            '<span class="locality">Guerrero Negro</span>, '
#                            '<span class="region">B.C.S.</span>, <span '
#                            'class="country-name">Mexico</span>',
#             'business_status': 'OPERATIONAL',
#             'formatted_address': 'Paralelo 28, México 1, 23940 Guerrero Negro, '
#                                  'B.C.S., Mexico',
#             'formatted_phone_number': '615 157 1305',
#             'geometry': {'location': {'lat': 28.001048, 'lng': -114.0138683},
#                          'viewport': {'northeast': {'lat': 28.0023810302915,
#                                                     'lng': -114.0121717197085},
#                                       'southwest': {'lat': 27.9996830697085,
#                                                     'lng': -114.0148696802915}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'international_phone_number': '+52 615 157 1305',
#             'name': 'The Halfway Inn',
#             'photos': [{'height': 4000,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/106097963895846752473">Roger '
#                                               'Norman</a>'],
#                         'photo_reference': 'AeJbb3fOXBF6lm5xt35Mja8nCo78bgfGfsSjgdKDpz7Y7Q0gc6Q8fxijHgqH-vjtNWafvm6zYsCq0QAc70UeK_h1oJYO0B78HQbcz5K0cps5cnqkf9TzJ1UKaKLiS_rGUv6KDXZy7Z3zlc57XsKMZLk0tE6ZIZWhnbSB_uKqcPpMPbBIh3_X',
#                         'width': 3000},
#                        {'height': 3456,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/105446408104625415284">Rosalba '
#                                               'Tejeda</a>'],
#                         'photo_reference': 'AeJbb3d18PuWnpvqPaarZSBtOjk0kpAXHWfBel_kqHC9iI1iE5B9pZlMbJQQamq70wRu_j1ejc4jssMCdQ-62OfhbSg6S_-7EyOT6XH8pbL-kPRfXfmoqRIamRh-Ngfl9PJ02dDoLVJua7cvZ68jmQjPhccEzbR2oaKyWaIKqZ5zqgJXDdrm',
#                         'width': 4608},
#                        {'height': 1536,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/112202468487503966925">Mario '
#                                               'fernando Origel regalado</a>'],
#                         'photo_reference': 'AeJbb3ezbfOd_D7N6mX_u6l6TQqogC2azJXiTIsXF7nNmADeDOI_CAypIiROOPKuIPVG5Dtm5IooDaEO0-1uW9ZOEWrGU5PmsTrgPl3koTOmziN2UxO78ah9t8nUI460WUy12ZZoSEvm3eFTWCrykrWl_gSUi08mX7g13NcYdPhy2xrVglhW',
#                         'width': 2048},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/113849610721951630997">Will '
#                                               'Pizzolato</a>'],
#                         'photo_reference': 'AeJbb3f8VCJfezEFqK6iq0goSZ_aHzTcOU0JzOjzI6nJ3UjGl4KHVkyjuSIz1h6j6XxZA8fasP6WD4Fy2rnnLGjWipDRKbWcM3IYj64mfbMUgxGWwiItxFn6TtoO9JN12GPkUp-57Eo-XF2lkE7EK3LqsYwL-T2UnEzQRvEWNMoHsN8EaQk9',
#                         'width': 4032},
#                        {'height': 2448,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib
reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucowWuJHdu4FKEI5ollCp-LUKxIjk1hPhsZth-M-=s128-c0x00000000-cc-rp-mo-ba5',
#                          'rating': 5,
#                          'relative_time_description': '3 months ago',
#                          'text': 'This is a wonderful place to stop and rest. '
#                                  'The hotel has a restaurant, a bar, souvenir '
#                                  'shop, billiards and ping pong. The rooms are '
#                                  "clean. It's a pleasant surprise for us to "
#                                  'find this hotel on our trip. The next decent '
#                                  'hotel is at least 5 or more hours either '
#                                  'direction. The staff are very friendly, '
#                                  'English is easy to use here. We had '
#                                  'breakfast and dinner at the restaurant, both '
#                                  'were good meals. Service was good, fast.',
#                          'time': 1650937553},
#                         {'author_name': 'scott ortar',
#                          'author_url': 'https://www.google.com/maps/contrib/110987480059288536145/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmmbZzrBb0q0sxMbH9zNSSa6qvI3NtohHwQW7hw8=s128-c0x00000000-cc-rp-mo',
#                          'rating': 4,
#                          'relative_time_description': 'a month ago',
#                          'text': 'Great place to rest , have a drink and food. '
#                                  'Thanks to Manuel for all he does to make '
#                                  'your stay comfortable and relaxing.. He’s '
#                                  'great!',
#                          'time': 1656097882},
#                         {'author_name': 'Frank Chambers',
#                          'author_url': 'https://www.google.com/maps/contrib/106872977119186298791/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucrPeNazof1oLumGSPL3HQWTYcstY7l5P85NzVJAS04=s128-c0x00000000-cc-rp-mo-ba6',
#                          'rating': 4,
#                          'relative_time_description': 'a month ago',
#                          'text': 'Maria Elena at front desk was so friendly, '
#                                  'our waiter Antonio was very attentive and '
#                                  'amazing service.  Lupita in the kitchen '
#                                  'cooked great food.  Great place to stay.',
#                          'time': 1655782905},
#                         {'author_name': 'Cherilyn Jones',
#                          'author_url': 'https://www.google.com/maps/contrib/117846175599779832042/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucoBSI4Z0_J1SPlXAoyxNhJOcFV5eEX7Hg1gS30V5A=s128-c0x00000000-cc-rp-mo-ba5',
#                          'rating': 5,
#                          'relative_time_description': '4 months ago',
#                          'text': 'I love Manuel.  He is at the '
#                                  'bar/restaurant.  “Happy wife happy life”, I '
#                                  'buy his wife’s bracelets and goodies every '
#                                  'time I come!!!   The guacamole is delish.  '
#                                  'He is a great conversationalist and so enjoy '
#                                  'time with him.  He helps me with my Spanish. '
#                                  'Rooms are clean and beds comfortable.  Water '
#                                  'pressure is great and hot water was awesome.',
#                          'time': 1646854263},
#                         {'author_name': 'Rhonda B.',
#                          'author_url': 'https://www.google.com/maps/contrib/102906927718876602574/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucogQLrJtvfQ6NSNhrYz1Fk505ta6TvchoJaywWczSQ=s128-c0x00000000-cc-rp-mo-ba4',
#                          'rating': 5,
#                          'relative_time_description': '2 months ago',
#                          'text': 'We love staying here. Great location and '
#                                  'friendly staff. Dog friendly too',
#                          'time': 1653939393}],
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'url': 'https://maps.google.com/?cid=6377778383683289505',
#             'user_ratings_total': 504,
#             'utc_offset': -420,
#             'vicinity': 'Paralelo 28, Carretera Federal 1, Guerrero Negro'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': 'French Polynesia',
#                                     'short_name': 'PF',
#                                     'types': ['country', 'political']},
#                                    {'long_name': 'Gambier',
#                                     'short_name': 'Gambier',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Îles Gambier',
#                                     'short_name': 'Îles Gambier',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': '98755',
#                                     'short_name': '98755',
#                                     'types': ['postal_code']}],
#             'adr_address': 'BP 19 | Archipel des Gambier, Mangareva, <span '
#                            'class="locality">Gambier</span> <span '
#                            'class="postal-code">98755</span>, <span '
#                            'class="country-name">French Polynesia</span>',
#             'business_status': 'OPERATIONAL',
#             'formatted_address': 'BP 19 | Archipel des Gambier, Mangareva, '
#                                  'Gambier 98755, French Polynesia',
#             'formatted_phone_number': '40 97 83 76',
#             'geometry': {'location': {'lat': -23.1276524, 'lng': -134.9656596},
#                          'viewport': {'northeast': {'lat': -23.1263721197085,
#                                                     'lng': -134.9643507197085},
#                                       'southwest': {'lat': -23.1290700802915,
#                                                     'lng': -134.9670486802915}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'international_phone_number': '+689 40 97 83 76',
#             'name': 'Pension Bianca & Benoit',
#             'photos': [{'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/102405645860592238312">Jean-Louis '
#                                               'GARRY</a>'],
#                         'photo_reference': 'AeJbb3d5hRcM9efGSBOImYZrh4lB_8X3qiEYtxu--VdnXiwfk56NBfbibxVd2Hn1-2fYA9q75FHHxQR207FD6_7_XAzFlJeAhNfq2I6bF6ZioVdemhYdXs6X8yJvWpglSQWKu3PnkOmBiTlZ2lP1UOSh0W3CUgwLrqOTxKXGkqcxX09PJCL0',
#                         'width': 4032},
#                        {'height': 2048,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/115150439809622095143">Frédérick '
#                                               'B.</a>'],
#                         'photo_reference': 'AeJbb3c01FxrweERiuXpb-9ewaqlX7lsyzdpV_J4Z-_nIOPugDtx3eZ4OB-WJX3_sjHgHEGoruJqFhf8z494NpDFmX23Qdzl9LRFRAGetOnNbjorRaSGdTMOXmQ3eXUy43BUE7Ba8nDP9wAeAeoRaX2tks8mhXjHrY9XdjAAbeWMTR_UcDPm',
#                         'width': 1536},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/102405645860592238312">Jean-Louis '
#                                               'GARRY</a>'],
#                         'photo_reference': 'AeJbb3eyRixXlYTj1KLIB0fMIyC_-cNbYhz38bZ9ZnFXrZdmH5ptX7yIbIa3PlmrqfmcqzOt0OCo8tCL2h-uRtOKX-beiA_FAmRlejUpu6_BaERjqdsnUICMLcloRZVAGnrJ-8LqMhHfT32uwXeKaoLohh4IByWbkm_r819GrCGmeEhtpRUJ',
#                         'width': 4032},
#                        {'height': 1536,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/115150439809622095143">Frédérick '
#                                               'B.</a>'],
#                         'photo_reference': 'AeJbb3drbu7oedSrkFOZyLIshWZ0JRsciWaDX_pBLN6U6n3rgSEJ8HHaWnYr7B4iuU3ZMP_FLmUPPxnPuDaKFmu7PPwXn-sRT1D8cuAWCQTALzHQdIhioq8ES0l7NThUZaMN9IH6fuF_4TEPytrojgUPHPvJSa-lwLxje2WAyLOzX2ziWprs',
#                         'width': 2048},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/102405645860592238312">Jean-Louis '
#                                               'GARRY</a>'],
#                         'photo_reference': 'AeJbb3fQo4DslvnIElmxa3RoTWMow5pWLU_4hRDvDo5tH8z3IqDhmu5FEp2oT6YRf-raYeUIVOG4929HpdnNWSlMQgcPm7OhiGDEbC50SFDGLc6Vp5F_WxFe-ZvGbQIZXYCkxDqk_R-9apsaqahqDw7_d51MXXrROayDXTB9SCM_NcR7D7Ng',
#                         'width': 4032},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/
reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucoLub1Bg5_jZFgFnBgt2HQG5qCP0yj2I_vQclqhBA=s128-c0x00000000-cc-rp-mo',
#                          'rating': 3,
#                          'relative_time_description': '11 months ago',
#                          'text': 'lonely',
#                          'time': 1630767635},
#                         {'author_name': 'Bryan',
#                          'author_url': 'https://www.google.com/maps/contrib/104853386452019505216/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucq_K1Tkq4YdJSQ4aC02JKmkc6yX6b7gaj-mF0gw5A=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': '4 years ago',
#                          'text': 'A 5 star re-known Hilton hotel compared to '
#                                  "Pitcairn Island's spare bedrooms. Fantastic "
#                                  'pork belly ramen. Had no idea they made such '
#                                  'good ramen out here especially since its so '
#                                  'hot all of the time. Prob why they never '
#                                  'have guests. Still, you should stay here if '
#                                  "you've ever been shipwrecked or lost at sea.",
#                          'time': 1512157691},
#                         {'author_name': 'condominio Terra',
#                          'author_url': 'https://www.google.com/maps/contrib/112128786214378783693/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmmfzN_8B6fq-y0mBBIR59Tb-gAmOFfLyBs91p_E=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': '6 years ago',
#                          'text': 'Nice seafood, fish, and coffe are very '
#                                  'good....',
#                          'time': 1441815896},
#                         {'author_name': 'Marie-Danièle PAULY',
#                          'author_url': 'https://www.google.com/maps/contrib/115316477780243731046/reviews',
#                          'language': 'en-US',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmnSoliODFQYLWEAbFJR089LVaG-7fdurnup05MM=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': 'a year ago',
#                          'text': 'Excellent address! Everything is done to '
#                                  'make your stay unforgettable. Welcome, '
#                                  'gastronomy, availability, a faultless!',
#                          'time': 1605895172},
#                         {'author_name': 'Ghislaine ROUCHON-MAZERAT',
#                          'author_url': 'https://www.google.com/maps/contrib/102810139958505459143/reviews',
#                          'language': 'en-US',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmm7KH9VHq8UFQdefwXPAq7tfPs0mlyQ9JaiD9Fq=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': 'a year ago',
#                          'text': 'An unforgettable stay in the Gambia. We were '
#                                  'considered part of the family and shared '
#                                  'Polynesian life.\n'
#                                  'Bianca and Benoît are adorable.',
#                          'time': 1604040837}],
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'url': 'https://maps.google.com/?cid=8730576922409147760',
#             'user_ratings_total': 14,
#             'utc_offset': -540,
#             'vicinity': 'BP 19 | Archipel des Gambier, Mangareva'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '5XWF+8MR',
#                                     'short_name': '5XWF+8MR',
#                                     'types': ['plus_code']},
#                                    {'long_name': 'Atuona',
#                                     'short_name': 'Atuona',
#                                     'types': ['sublocality_level_1',
#                                               'sublocality',
#                                               'political']},
#                                    {'long_name': 'Hiva Oa',
#                                     'short_name': 'Hiva Oa',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Southern Group',
#                                     'short_name': 'Southern Group',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': 'Marquesas Islands',
#                                     'short_name': 'Marquesas Islands',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': 'French Polynesia',
#                                     'short_name': 'PF',
#                                     'types': ['country', 'political']}],
#             'adr_address': '5XWF+8MR, <span class="locality">Hiva Oa</span>, '
#                            '<span class="country-name">French Polynesia</span>',
#             'business_status': 'OPERATIONAL',
#             'formatted_address': '5XWF+8MR, Hiva Oa, French Polynesia',
#             'formatted_phone_number': '40 92 75 87',
#             'geometry': {'location': {'lat': -9.8041391, 'lng': -139.0258483},
#                          'viewport': {'northeast': {'lat': -9.802782919708498,
#                                                     'lng': -139.0242453697085},
#                                       'southwest': {'lat': -9.805480880291503,
#                                                     'lng': -139.0269433302915}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             

#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/111287495942271386637">Pierre '
#                                               'Vander Heyden</a>'],
#                         'photo_reference': 'AeJbb3eVKn91K4dNg7izqNTzcDTXRm4aJR80xH5Eyu24iqEhHxesLiwJt1M_39D4Tz8Ehj8lei2OUqjLEfp53V6J0qSVHsFC_rAoPXFlhXEPSKp1o5g23oFYRhuRgeYN3_7ex0oSbCcwcJpZU2USorsi7xq1wiLyg-mfRK_6ksf7oqskRT59',
#                         'width': 4192},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/113837986991858775771">Henk '
#                                               'Hindriks</a>'],
#                         'photo_reference': 'AeJbb3eI-Z7vAcjmLUbs-BIAQKXxKDbwXq-opzWv1-oyAT1CXYU_LHkvY2w16ySE-oaRXoqbGZmZHwPcYxiDRY1h40ShnQ0fYc_RtMZbxqYksPEwCL3-UTfZ19Eh7jJvJqH_GTcXAnOLu2A-H-D6_ibEX5gjfoCqYLvDJ3Ke7tRQ7r4FxeWD',
#                         'width': 4032},
#                        {'height': 1536,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/103791037825406985867">Eric '
#                                               'Baude</a>'],
#                         'photo_reference': 'AeJbb3c8G1aytl1EFrpBG5-DTVC8ZeAosNrzFRafO_SwjjEs5ytKM3RvYV-TbZPRmgXPDGbQF0VrXUXjqJHzpahSka_kRpN9_tGLFL4wtOFEbI6_NSFCz1I5Uugl0lvr4ZCsgE0DY5aWR7cnGOqpNOh7XA3WIX2DfoibTCZ7PVuIXDeFVpeS',
#                         'width': 2048},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/113837986991858775771">Henk '
#                                               'Hindriks</a>'],
#                         'photo_reference': 'AeJbb3eyIX9NyTeFHgGtqnijKxeovbV1a38lVqMyln65sqPjNcyrJg1ICkuyGz-KvZLOMpi3I7NyyQ9QLshaabak76y44RY07mMjHSGVl5yGAiKl0WMogpo8mTeu0eY_Mw2yk7yZbJzcHVxemrFEkAm4kHvfTQkcBdgAcMx6D0nDMf7Lq49I',
#                         'width': 4032}],
#             'place_id': 'ChIJL4z7-PMhN3YRhdXuLcxVEH4',
#             'rating': 4.3,
#             'reference': 'ChIJL4z7-PMhN3YRhdXuLcxVEH4',
#             'reviews': [{'author_name': 'Andrzej Kupisz',
#                          'author_url': 'https://www.google.com/maps/contrib/104629446096495443713/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmmT2AnoS3PuFJ3RsfdfkumDcmI7uj5q9mCRaf0G=s128-c0x00000000-cc-rp-mo-ba4',
#                          'rating': 5,
#                          'relative_time_description': 'a month ago',
#                          'text': 'Graet place with amazing views! Very '
#                                  'hospitable Staff. Manager Jean Jaques very '
#                                  'helpfull. Many Thanks to all!',
#                          'time': 1654278332},
#                         {'author_name': 'Kathleen Chicago',
#                          'author_url': 'https://www.google.com/maps/contrib/106562619337650228519/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZuco75ETHD3Ws2H15mmfbp3Zo3QYPkScXLUE1em9SPA=s128-c0x00000000-cc-rp-mo-ba3',
#                          'rating': 5,
#                          'relative_time_description': '8 months ago',
#                          'text': 'Best place in the Marquesas! Luxury '
#                                  'experience. Gorgeous views.',
#                          'time': 1637640790},
#                         {'author_name': 'Patrick Zeitouni',
#                          'author_url': 'https://www.google.com/maps/contrib/106606712350547249271/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucpD_c5M9o2Km71ErWiHj75s07ItBM1XvHD_StodcDQ=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': 'a year ago',
#                          'text': 'Spectacular views, stellar accomodations and '
#                                  'professional, friendly staff.',
#                          'time': 1601677559},
#                         {'author_name': 'DJ',
#                          'author_url': 'https://www.google.com/maps/contrib/111657181174141795826/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucoyvcIqszAWmY4J4Fodv6BCDhM4nJ0B4nv3gjseWg=s128-c0x00000000-cc-rp-mo-ba5',
#                          'rating': 5,
#                          'relative_time_description': 'a year ago',
#                          'text': 'Really nice stay here. Was very quiet, '
#                                  'plenty of parking, and they provided a lot '
#                                  'of great information for getting around the '
#                                  'island and food recommendations.',
#                          'time': 1603813727},
#                         {'author_name': 'Greg Hanson',
#                          'author_url': 'https://www.google.com/maps/contrib/118281955878407513804/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmm0GThVv4jtGrCi_dh4pzbXCZdx0hIuw_4_oxdK=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': '4 years ago',
#                          'text': 'Great Lodge for a stay in Atuona. Excellent '
#                                  'food, friendly staff and bungalows were very '
#                                  'comfortable.',
#                          'time': 1521211299}],
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'url': 'https://maps.google.com/?cid=9083854783838606725',
#             'user_ratings_total': 58,
#             'utc_offset': -570,
#             'vicinity': '5XWF+8MR, Hiva Oa',
#             'website': 'https://www.hotelhanakee.com/'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': 'Ara Tapu',
#                                     'short_name': 'Ara Tapu',
#                                     'types': ['route']},
#                                    {'long_name': 'Kaikaveka Tapere',
#                                     'short_name': 'Kaikaveka Tapere',
#                                     'types': ['sublocality_level_1',
#                                               'sublocality',
#                                               'political']},
#                                    {'long_name': 'Avarua District',
#                                     'short_name': 'Avarua District',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Cook Islands',
#                                     'short_name': 'CK',
#                                     'types': ['country', 'political']}],
#             'adr_address': '<span class="street-address">Ara Tapu</span>, '
#                            '<span class="locality">Avarua District</span>, '
#                            '<span class="country-name">Cook Islands</span>',
#             'business_status': 'OPERATIONAL',
#             'formatted_address': 'Ara Tapu, Avarua District, Cook Islands',
#             'formatted_phone_number': '21 003',
#             'geometry': {'location': {'lat': -21.1990528, 'lng': -159.7957},
#                          'viewport': {'northeast': {'lat': -21.1978665197085,
#                                                     'lng': -159.7943695197085},
#                                       'southwest': {'lat': -21.2005644802915,
#                                                     'lng': -159.7970674802915}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'international_phone_number': '+682 21 003',
#             'name': 'The Islander Hotel',
#             'opening_hours': {'open_now': True,
#                               'periods': [{'open': {'day': 0, 'time': '0000'}}],
#                               'weekday_text': ['Monday: Open 24 hours',
#                                                'Tuesday: Open 24 hours',
#                                                'Wednesday: Open 24 hours',
#                                                'Thursday: Open 24 hours',
#                                                'Friday: Open 24 hours',
#                                                'Saturday: Open 24 hours',
#                                                'Sunday: Open 24 hours']},
#             'photos': [{'height': 770,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/116182363482589837891">The '
#                                               'Islander Hotel</a>'],
#                         'photo_reference': 'AeJbb3doK5z6aI98VQ-1riZCmQNG42mn_UbgDX-aCA2yZeTqZxOI3l9UgeVbI_TP51IInhuDDu_vy4_tCsAp7gxE6oD5QG3QQ9DD4d9qKdV_IrxsKyBNW7MYfRo2aS8g5PU8Dmn7FKbh7jiouXqGevcu08d5T9nqSVvKcQEcRikD2iPggjz2',
#                         'width': 1368},
#                        {'height': 4608,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib

#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/116182363482589837891">The '
#                                               'Islander Hotel</a>'],
#                         'photo_reference': 'AeJbb3fRkWQ2JjgVlWlxfrJYedAzvJ8TEYkXe3Yu5npQ9q6U6hJW5UxWmqG63ctv30cTsQyHatqgCxxKyI2_4S2CuXKIjO3rucbXVLS_96ReRwLNEpMA_mO9S7wBJVkpoceXLOcrye7T33SIwdT5PSaAos1mUtdPC5bLb1-uPcZ_WmMi0mWz',
#                         'width': 2736}],
#             'place_id': 'ChIJmVoxwbjRV3ERXkJfFo6QLjY',
#             'plus_code': {'compound_code': 'R623+9P Avarua District, Cook '
#                                            'Islands',
#                           'global_code': '53C2R623+9P'},
#             'rating': 4,
#             'reference': 'ChIJmVoxwbjRV3ERXkJfFo6QLjY',
#             'reviews': [{'author_name': 'Denisr Robertson',
#                          'author_url': 'https://www.google.com/maps/contrib/101029197148668623092/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmlWPLFvYrFlvX3LtyC53Q6v3kZsIT3m5JoCMofO=s128-c0x00000000-cc-rp-mo',
#                          'rating': 4,
#                          'relative_time_description': '3 weeks ago',
#                          'text': 'Went to  the Island buffet night last week. '
#                                  'I think it was good value for money. We '
#                                  'enjoyed the show,very friendly staff. Lovely '
#                                  'refreshing cocktails . Would like the music '
#                                  'while having dinner to be softer was hard to '
#                                  'have a conversation with other guests. Worth '
#                                  'going to.',
#                          'time': 1657012611},
#                         {'author_name': 'John “John” Rader',
#                          'author_url': 'https://www.google.com/maps/contrib/113637355427300199268/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmldtMGg0PotuieFine0V6gRGEOT20hdOzLJYeHo=s128-c0x00000000-cc-rp-mo-ba3',
#                          'rating': 5,
#                          'relative_time_description': 'in the last week',
#                          'text': 'we booked in for a seven day holiday. room '
#                                  'was clean and fresh, staff were brilliant '
#                                  'and always friendly and helpful.The food '
#                                  'selection  and island night were great value '
#                                  'topped off with great priced cocktails and '
# ...
#                          'text': 'The beach across the street is excellent, '
#                                  'hundreds of feet of shallow perfect for '
#                                  "toddlers or just sitting in. There's a jet "
#                                  'ski and umbrella/chair rental place right '
#                                  'across the street as well. Only negative is '
#                                  'it would be nice if there was even a marked '
#                                  'off crosswalk for crossing to the beach. The '
#                                  'hotel pool and other amenities are also '
#                                  'great.',
#                          'time': 1655576101},
#                         {'author_name': 'Rachel Higgins',
#                          'author_url': 'https://www.google.com/maps/contrib/102227167696539246832/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucpTVOtx8Jvy72AcCTu4As7vcK1HlClU_hB2BKyztmI=s128-c0x00000000-cc-rp-mo-ba4',
#                          'rating': 5,
#                          'relative_time_description': 'a month ago',
#                          'text': 'Happy with my stay! I visited for a business '
#                                  'trip, but the hotel is right across from the '
#                                  'beach, where there looked to be '
#                                  'umbrella/chair rentals. It was close to '
#                                  'several restaurants and less than 5 minutes '
#                                  'from downtown. The lobby is beautiful, and '
#                                  'the bistro/bar looked nice as well. There '
#                                  'were a few minor cosmetic things in the room '
#                                  'like a cracked tile in the shower but '
#                                  'nothing that really impacts the experience. '
#                                  'One elevator was out of order, but they were '
#                                  'forthcoming with telling us and were '
#                                  'apologetic. Overall, the staff were very '
#                                  'friendly and helpful — great dinner '
#                                  'recommendations too. I would definitely stay '
#                                  'again for business or leisure!',
#                          'time': 1655946870},
#                         {'author_name': 'Jackson Grice',
#                          'author_url': 'https://www.google.com/maps/contrib/107945892123187272645/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucrtlizgWxvAeIa9bJ9n_14hLDtB0ZC68MTjUAuGwHQ=s128-c0x00000000-cc-rp-mo-ba2',
#                          'rating': 4,
#                          'relative_time_description': 'in the last week',
#                          'text': 'Great location close to the Beach and '
#                                  'restaurants/bars. The internet was messed up '
#                                  'and my room was missing the remote, but it '
#                                  'was quickly fixed. I would recommend staying '
#                                  'here, very family friendly and lot to do '
#                                  'within walking distance.',
#                          'time': 1659231723},
#                         {'author_name': 'Penny Jones',
#                          'author_url': 'https://www.google.com/maps/contrib/117745691946369737173/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZuco62efBNpKGgtqxnuggWc6cs8e7EBCDxGIQbcbpECI=s128-c0x00000000-cc-rp-mo',
#                          'rating': 2,
#                          'relative_time_description': '4 weeks ago',
#                          'text': 'My secretary booked my room for a '
#                                  "conference. When I arrived they didn't have "
#                                  'my reservation right so I had to wait on the '
#                                  'manager. The lobby area seemed to be ok but '
#                                  'once I got the key to go to my room totally '
#                                  'different story. Carpet old, rooms need '
#                                  "updating. I didn't stay. Went to another "
#                                  'hotel. Staff was nice hotel not...',
#                          'time': 1656863459}],
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'url': 'https://maps.google.com/?cid=10633279012834478487',
#             'user_ratings_total': 1159,
#             'utc_offset': -300,
#             'vicinity': '1600 East Beach Boulevard, Gulfport',
#             'website': 'https://www.marriott.com/en-us/hotels/gptcy-courtyard-gulfport-beachfront/overview/?scid=f2ae0541-1279-4f24-b197-a979c79310b0'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '12',
#                                     'short_name': '12',
#                                     'types': ['street_number']},
#                                    {'long_name': 'Naberezhnaya Ulitsa',
#                                     'short_name': 'Naberezhnaya Ulitsa',
#                                     'types': ['route']},
#                                    {'long_name': 'Strelka',
#                                     'short_name': 'Strelka',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Yeniseysky District',
#                                     'short_name': 'Yeniseysky District',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': 'Krasnoyarskiy kray',
#                                     'short_name': 'Krasnoyarskiy kray',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': 'Russia',
#                                     'short_name': 'RU',
#                                     'types': ['country', 'political']},
#                                    {'long_name': '663140',
#                                     'short_name': '663140',
#                                     'types': ['postal_code']}],
#             'adr_address': '<span class="street-address">Naberezhnaya Ulitsa, '
#                            '12</span>, <span class="locality">Strelka</span>, '
#                            '<span class="region">Krasnoyarskiy kray</span>, '
#                            '<span class="country-name">Russia</span>, <span '
#                            'class="postal-code">663140</span>',
#             'business_status': 'OPERATIONAL',
#             'formatted_address': 'Naberezhnaya Ulitsa, 12, Strelka, '
#                                  'Krasnoyarskiy kray, Russia, 663140',
#             'geometry': {'location': {'lat': 58.08646390000001,
#                                       'lng': 93.02218359999999},
#                          'viewport': {'northeast': {'lat': 58.08784548029151,
#                                                     'lng': 93.0234341302915},
#                                       'southwest': {'lat': 58.0851475197085,
#                                                     'lng': 93.0207361697085}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Gostinitsa "Angara"',
#             'photos': [{'height': 1080,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/

#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/100373258329660655157">Никита '
#                                               'Корнеев</a>'],
#                         'photo_reference': 'AeJbb3eIZ2D3q2KecZgQsL9bMol11jPV-r9NoAkkyCkA23cjVE4ckaJwvT557F1WYRtzKrZ_s5zzIImyun6mC2uLiPkZRa91VKzzwlzdX99CimLkVCx4xCJtRiq3kFByqoIR2AtUP6T5X5DiKOFths784kjUuQXw7qjGwshQpXOQNYcxz2YY',
#                         'width': 1080}],
#             'place_id': 'ChIJqUPbn68z0FwRYaXCDz1WF0M',
#             'plus_code': {'compound_code': '32PC+HV Strelka, Krasnoyarsk Krai, '
#                                            'Russia',
#                           'global_code': '9MCM32PC+HV'},
#             'rating': 3.6,
#             'reference': 'ChIJqUPbn68z0FwRYaXCDz1WF0M',
#             'reviews': [{'author_name': 'Руслан Абрамсон',
#                          'author_url': 'https://www.google.com/maps/contrib/110447870952541988150/reviews',
#                          'language': 'en-US',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucpKwq4BZITq5rJ8zaAetNSt3EGZQSL3Qb95fCoY=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': '9 months ago',
#                          'text': 'Very polite staff and reasonable prices in '
#                                  'clean rooms.',
#                          'time': 1633840115},
#                         {'author_name': 'Альбина Копылова',
#                          'author_url': 'https://www.google.com/maps/contrib/111559352034819214938/reviews',
#                          'language': 'en-US',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmnPvVZY6lE78OB5P-Oim_HUZpWa_AebaKsYX0ce=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': 'a year ago',
#                          'text': 'Nice hotel. Clean rooms, good service.',
#                          'time': 1621984752},
#                         {'author_name': 'Сергей Марков',
#                          'author_url': 'https://www.google.com/maps/contrib/115861046108306865808/reviews',
#                          'language': 'en-US',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmmUmQGL-DCe1HCa45yAiKGvsFQi0Iq4PFCDQFWH=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': 'a year ago',
#                          'text': 'Cool! Not expected!',
#                          'time': 1622052631},
#                         {'author_name': 'topWasp topWasp',
#                          'author_url': 'https://www.google.com/maps/contrib/115614194570509569535/reviews',
#                          'language': 'en-US',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AFdZucpddEykIMEpoxVZgsXr85exUvBL8xHoHZixrgxS=s128-c0x00000000-cc-rp-mo',
#                          'rating': 1,
#                          'relative_time_description': 'a year ago',
#                          'text': 'The conditions are very bad, the shower is '
#                                  'something with something, the talking '
#                                  'administrators are behind the wall in the '
#                                  'morning, not even a trash can in the room, '
#                                  'ugh',
#                          'time': 1608607253},
#                         {'author_name': 'Муминов Техрон',
#                          'author_url': 'https://www.google.com/maps/contrib/108690226360606607970/reviews',
#                          'language': 'en-US',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/AItbvmk8OrT7lq4bU7_znVE4hk4CHNmrb6sGgUrFymOw=s128-c0x00000000-cc-rp-mo',
#                          'rating': 1,
#                          'relative_time_description': '10 months ago',
#                          'text': 'Yes',
#                          'time': 1632441393}],
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'url': 'https://maps.google.com/?cid=4834427545262925153',
#             'user_ratings_total': 35,
#             'utc_offset': 420,
#             'vicinity': 'Naberezhnaya Ulitsa, 12, Strelka'},
#  'status': 'OK'}

# %%
cleanhotel_df
# Out:
#                                                   JSON                 DATE  \
# 10   {'coord': {'lon': -114.0611, 'lat': 27.9769}, ...  2022-07-31 02:58:37
# 35   {'coord': {'lon': -134.9692, 'lat': -23.1203},...  2022-07-31 02:59:30
# 37   {'coord': {'lon': -139.0333, 'lat': -9.8}, 'we...  2022-07-31 02:59:34
# 41   {'coord': {'lon': -159.775, 'lat': -21.2078}, ...  2022-07-31 02:59:41
# 48   {'coord': {'lon': -17.1, 'lat': 32.6667}, 'wea...  2022-07-31 02:59:55
# 75   {'coord': {'lon': -149.8667, 'lat': -17.5667},...  2022-07-31 03:00:47
# 105  {'coord': {'lon': -89.0928, 'lat': 30.3674}, '...  2022-07-31 02:57:51
# 121  {'coord': {'lon': 93.0344, 'lat': 58.0728}, 'w...  2022-07-31 03:02:19
#
#                CITY COUNTRY      LAT       LNG  MAX_TEMP  HUMIDITY  \
# 10   Guerrero Negro      MX  27.9769 -114.0611     70.70      77.0
# 35          Rikitea      PF -23.1203 -134.9692     72.93      75.0
# 37           Atuona      PF  -9.8000 -139.0333     76.68      78.0
# 41           Avarua      CK -21.2078 -159.7750     78.85      69.0
# 48     Ponta do Sol      PT  32.6667  -17.1000     69.94      79.0
# 75          Haapiti      PF -17.5667 -149.8667     79.72      66.0
# 105        Gulfport      US  30.3674  -89.0928     73.74      71.0
# 121         Strelka      RU  58.0728   93.0344     74.44      71.0
#
#      CLOUDINESS  WIND_SPEED                HOTEL_PLACEID HOTEL_NAME  \
# 10          5.0       13.85  ChIJZ-lVpeL4M4ERoYGbJ6Zrglg       NULL
# 35          9.0       15.93  ChIJib4T7laIJ54RcJ1rUHQ9KXk       NULL
# 37         14.0       14.43  ChIJL4z7-PMhN3YRhdXuLcxVEH4       NULL
# 41         40.0       20.71  ChIJmVoxwbjRV3ERXkJfFo6QLjY       NULL
# 48         14.0        6.98  ChIJU0wF3-hZYAwRokB97zLZkqY       NULL
# 75         14.0       22.12  ChIJlQlAZRqImXYR6WtP_FwQONA       NULL
# 105         1.0        8.32  ChIJX363D8QXnIgRl4mdtez-kJM       NULL
# 121        35.0        7.09  ChIJqUPbn68z0FwRYaXCDz1WF0M       NULL
#
#                                             HOTEL_CITY HOTEL_COUNTRY
# 10   Paralelo 28, México 1, 23940 Guerrero Negro, B...          NULL
# 35   BP 19 | Archipel des Gambier, Mangareva, Gambi...          NULL
# 37                 5XWF+8MR, Hiva Oa, French Polynesia          NULL
# 41             Ara Tapu, Avarua District, Cook Islands          NULL
# 48                 VE3 10, 9360 Ponta do Sol, Portugal          NULL
# 75   PK 20 Vaianae Haapiti Moorea, Moorea-Maiao 987...          NULL
# 105         1600 E Beach Blvd, Gulfport, MS 39501, USA          NULL
# 121  Naberezhnaya Ulitsa, 12, Strelka, Krasnoyarski...          NULL

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap

info_box_template = """
<dl>
<dt>Name</dt><dd>{HOTEL_NAME}</dd>
<dt>City</dt><dd>{HOTEL_CITY}</dd>
<dt>Country</dt><dd>{HOTEL_COUNTRY}</dd>
</dl>
"""

# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name

hotel_info = [info_box_template.format(**row) for index, row in df.iterrows()]
locations = df[["LAT", "LNG"]]

# %%
# Add marker layer ontop of heat map

 # Assign the marker layer to a variable
    
markers = gmaps.marker_layer(locations=locations, display_info_box=True, info_box_content=hotel_info)

# Add the layer to the map

fig.add_layer(markers)
fig


# Display figure
